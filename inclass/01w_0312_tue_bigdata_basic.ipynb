# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2024-1-BDA/blob/main/inclass/01w_0312_tue_bigdata_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# ## 01주 2024-0312-화

# %% [markdown]
# ### 파이썬 설치 확인

# %%
import sys
sys.version
# Out:
# '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 1.25.2
# 1.5.3

# %% [markdown]
# ## 코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib

# %% [markdown]
# ## 그래프 해상도 설정

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})

# %%
# 해상도 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목')
plt.xlabel('간단한 그래프')
plt.show()

# %%
plt.plot(range(-20, 80), np.random.randn(100).cumsum(), 'b-.')
plt.title('한글 점검');

# %%
x = np.random.randint(1, 100, 50)
x
# Out:
# array([80, 47,  1, 85, 27, 36, 91, 29, 35, 81, 37, 81, 13,  8, 14, 53, 77,
#        78, 12, 76, 58, 48, 71, 25, 48, 30, 76, 46, 49, 12, 42, 81, 85,  4,
#        33, 65, 72, 15, 78, 35, 43, 54, 72, 40, 51, 69, 71, 23, 16, 73])

# %%
x = np.random.randint(1, 100, 50)
y = np.random.randint(50, 80, 50)
s = np.random.randint(50, 300, 50)

plt.scatter(x, y, s=s, alpha=.4)
plt.title('산점도');

# %% [markdown]
# ## seaborn 데이터 시각화

# %%
var = ['a', 'a', 'b', 'c', 'b', 'a']
var
# Out:
# ['a', 'a', 'b', 'c', 'b', 'a']

# %%
import seaborn as sns
sns.countplot(var);

# %%
sns.countplot(x = var);

# %% [markdown]
# ## 데이터분석을 위한 seaborn 내장(토이) 데이터

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### 타이타닉 열(변수) 설명
# - survived : 0 = 사망, 1 = 생존
# - pclass : 1 = 1등석, 2 = 2등석, 3 = 3등석
# - sex : male = 남성, female = 여성
# - age : 나이
# - sibsp : 타이타닉 호에 동승한 자매 / 배우자의 수
# - parch : 타이타닉 호에 동승한 부모 / 자식의 수
# - fare : 티켓 요금
# - embarked : 탑승지, C = 셰르부르, Q = 퀸즈타운, S = 사우샘프턴
# - class : First = 1등석, Second = 2등석, Third = 3등석
# - who : 남/여/아이, 'man', 'woman', 'child'
# - adult_male : 남자 어른, True/False
# - deck : 방 위치, 'A', 'B', 'C', 'D', 'E', 'F', 'G', NaN
# - embark_town : 탑승지
# - alive : 생존, yes/no
# - alone : 1인 탑승, True/False
