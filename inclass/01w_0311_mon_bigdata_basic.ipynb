# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2024-1-BDA/blob/main/inclass/01w_0311_mon_bigdata_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# # 01주 2024-0311-월

# %% [markdown]
# ## 파이썬 설치 확인

# %%
import sys
sys.version
# Out:
# '3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 1.25.2
# 1.5.3

# %% [markdown]
# ## 코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 18.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 그래프 해상도 설정

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})

# %%
# 해상도 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목')
plt.xlabel('간단한 그래프')
plt.show()

# %%
plt.plot(range(-20, 80), np.random.randn(100).cumsum(), 'r--')
plt.title('한글 점검');

# %%
x = np.random.randint(1, 100, 50)
y = np.random.randint(50, 80, 50)
s = np.random.randint(50, 300, 50)

plt.scatter(x, y, s=s, alpha=.4)
plt.title('산점도');

# %% [markdown]
# ## seaborn data vis

# %%
import seaborn as sns

# %%
var = ['a', 'a', 'b', 'c']
var
# Out:
# ['a', 'a', 'b', 'c']

# %%
sns.countplot(var);

# %%
sns.countplot(x = var);

# %% [markdown]
# ## 데이터분석을 위한 토이 데이터

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
